# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
headers = ['Limit','Max Revenue','Optimal Revenue']
df = pd.read_csv('Plot.csv',names=headers)
df = df[1:]
df
# Out:
#                   Limit          Max Revenue     Optimal Revenue
# 1                   0.0    4.192150955869033   5.987166564356233
# 2                 0.024    1.736496724068021  2.3468020318248324
# 3                 0.048    1.941292146882306   2.229256559059194
# 4   0.07200000000000001    6.021780382754555  10.163983436842049
# 5                 0.096    6.355109150247259  18.053059897189474
# 6                  0.12    1.916673454920264  18.053059897189474
# 7                 0.144   3.4604549022755897   9.507286473479992
# 8                 0.168  0.35885876967447616   9.507286473479992
# 9                 0.192   3.8905619578876283   9.507286473479992
# 10                0.216   2.8071996543935382    9.97390041712332
# 11  0.24000000000000002   2.2600520378841154   4.532549126165273
# 12                0.264   1.2177905550843775   4.532549126165273
# 13  0.28800000000000003    1.283681375948921   4.532549126165273
# 14  0.31200000000000006    3.101146450288372   4.532549126165273
# 15  0.33600000000000013    3.443415561021518   4.532549126165273
# 16   0.3600000000000001   3.2915775362555793   4.532549126165273
# 17   0.3840000000000001     2.91923489413786   4.532549126165273
# 18  0.40800000000000014   1.1951017084978883   4.532549126165273
# 19  0.43200000000000016   2.2757420337614627   4.532549126165273
# 20   0.4560000000000002   0.8590239825206069   4.532549126165273
# 21   0.4800000000000002   2.2991236417648437   4.532549126165273
# 22   0.5040000000000002    2.217467438524739   4.532549126165273
# 23   0.5280000000000002    2.098160045678989   4.532549126165273
# 24   0.5520000000000003   1.6564255952302684   4.532549126165273
# 25   0.5760000000000003   2.2079476378399603   4.532549126165273
# 26   0.6000000000000003   1.1003826964800993   4.532549126165273
# 27   0.6240000000000003    1.940070944325712   4.532549126165273
# 28   0.6480000000000004   1.0260248513324426   4.532549126165273
# 29   0.6720000000000004   0.6914965371630348   4.532549126165273
# 30   0.6960000000000004   2.3595974254848637  12.491112324547824
# 31   0.7200000000000004   1.1481534352025844  12.491112324547824
# 32   0.7440000000000004   1.6155757845394874  12.491112324547824
# 33   0.7680000000000005    4.381771499610643  16.066631069701106
# 34   0.7920000000000005   1.5340641990611763  16.066631069701106
# 35   0.8160000000000005    3.359465431460692  16.066631069701106
# 36   0.8400000000000005   0.6413736736704658  16.066631069701106
# 37   0.8640000000000005    1.356563879567172  16.066631069701106
# 38   0.8880000000000006    1.025375127861173  16.066631069701106
# 39   0.9120000000000006   0.3184659475393883  16.066631069701106
# 40   0.9360000000000006   2.3709397042763727  16.066631069701106
# 41   0.9600000000000006   0.9879355895627099  16.066631069701106
# 42   0.9840000000000007   0.3836377208083245  16.066631069701106
# 43   1.0080000000000007    3.890687457161981   10.34925104784043
# 44    1.032000000000001    1.864861638518128   10.34925104784043
# 45   1.0560000000000012   0.5093116411487932   10.34925104784043
# 46   1.0800000000000012    1.316380917494659   10.34925104784043
# 47   1.1040000000000012   2.9106308017045457   10.34925104784043
# 48   1.1280000000000012   0.9437904955947476   10.34925104784043
# 49   1.1520000000000012    7.856575612009292  19.056699808118733
# 50   1.1760000000000013   1.9914997245048904  19.056699808118733

# %%
#df['Date'] = df['Date'].map(lambda x: datetime.strptime(str(x), '%Y/%m/%d %H:%M:%S.%f'))
# x = df['Limit']
# y = [df['Optimal Revenue'],df["Max Revenue"]]
# # plot
# plt.plot(x,y)
# # beautify the x-labels
# plt.gcf().autofmt_xdate()
df=df.astype(float)

df.plot(x='Limit', y=['Max Revenue', 'Optimal Revenue'], figsize=(10,5), grid=True)
#df[["Limit","Max Revenue","Optimal Revenue"]].plot(x="Limit")
# df.plot(x="Limit", y="Optimal Revenue", ax=ax, color="C2")


plt.show()

# %%
max_max_till_now = 0
max_opt_till_now = 0
df2 = pd.DataFrame()
for index, row in df.iterrows():
    if(row['Limit']>0.3 and row['Max Revenue']>=max_max_till_now and row['Optimal Revenue']>=max_opt_till_now):
        data = pd.DataFrame({"Limit": row['Limit'],"Max Revenue": row['Max Revenue'],"Optimal Revenue":row['Optimal Revenue']})
        df2.append(data,ignore_index=True)
        max_max_till_now = row['Max Revenue']
        max_opt_till_now = row['Optimal Revenue']
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-30e7cfad2e16> in <module>()
#       4 for index, row in df.iterrows():
#       5     if(row['Limit']>0.3 and row['Max Revenue']>=max_max_till_now and row['Optimal Revenue']>=max_opt_till_now):
# ----> 6         data = pd.DataFrame({"Limit": row['Limit'],"Max Revenue": row['Max Revenue'],"Optimal Revenue":row['Optimal Revenue']})
#       7         df2.append(data,ignore_index=True)
#       8         max_max_till_now = row['Max Revenue']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in extract_index(data)
#    7391
#    7392         if not indexes and not raw_lengths:
# -> 7393             raise ValueError('If using all scalar values, you must pass'
#    7394                              ' an index')
#    7395
#
# ValueError: If using all scalar values, you must pass an index

# %%
df=df.astype(float)

df.plot(x='Limit', y=['Max Revenue', 'Optimal Revenue'], figsize=(10,5), grid=True)
#df[["Limit","Max Revenue","Optimal Revenue"]].plot(x="Limit")
# df.plot(x="Limit", y="Optimal Revenue", ax=ax, color="C2")


plt.show()
